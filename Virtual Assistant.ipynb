# %%
pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in c:\anaconda\lib\site-packages (3.8.1)Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Using cached pyttsx3-2.90-py3-none-any.whl (39 kB)
# Requirement already satisfied: comtypes; platform_system == "Windows" in c:\anaconda\lib\site-packages (from pyttsx3) (1.1.7)
# Collecting pypiwin32; platform_system == "Windows"
#   Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# Requirement already satisfied: pywin32; platform_system == "Windows" in c:\anaconda\lib\site-packages (from pyttsx3) (227)
# Installing collected packages: pypiwin32, pyttsx3
# Successfully installed pypiwin32-223 pyttsx3-2.90
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda pyaudio
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Anaconda
#
#   added / updated specs:
#     - pyaudio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.10.14 |                0         159 KB  anaconda
#     conda-4.10.1               |   py38haa95532_1         2.9 MB
#     openssl-1.1.1h             |       he774522_0         5.8 MB  anaconda
#     portaudio-19.6.0           |       he774522_4         240 KB  anaconda
#     pyaudio-0.2.11             |   py38he774522_2         189 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         9.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   portaudio          anaconda/win-64::portaudio-19.6.0-he774522_4
#   pyaudio            anaconda/win-64::pyaudio-0.2.11-py38he774522_2
#
# The following packages will be UPDATED:
#
#   conda                                4.9.2-py38haa95532_0 --> 4.10.1-py38haa95532_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                 pkgs/main --> anaconda
#   openssl                                         pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2020 | 159 KB    |            |   0%
# ca-certificates-2020 | 159 KB    | #          |  10%
# ca-certificates-2020 | 159 KB    | ###        |  30%
# ca-certificates-2020 | 159 KB    | ####       |  40%
# ca-certificates-2020 | 159 KB    | #####      |  50%
# ca-certificates-2020 | 159 KB    | ######     |  60%
# ca-certificates-2020 | 159 KB    | #######    |  70%
# ca-certificates-2020 | 159 KB    | ########   |  80%
# ca-certificates-2020 | 159 KB    | #########  |  90%
# ca-certificates-2020 | 159 KB    | ########## | 100%
# ca-certificates-2020 | 159 KB    | ########## | 100%
#
# pyaudio-0.2.11       | 189 KB    |            |   0%
# pyaudio-0.2.11       | 189 KB    | 8          |   8%
# pyaudio-0.2.11       | 189 KB    | ##5        |  25%
# pyaudio-0.2.11       | 189 KB    | ###3       |  34%
# pyaudio-0.2.11       | 189 KB    | ####2      |  42%
# pyaudio-0.2.11       | 189 KB    | #####      |  51%
# pyaudio-0.2.11       | 189 KB    | #####9     |  59%
# pyaudio-0.2.11       | 189 KB    | ######7    |  68%
# pyaudio-0.2.11       | 189 KB    | #######6   |  76%
#
# Note: you may need to restart the kernel to use updated packages.
# pyaudio-0.2.11       | 189 KB    | ########4  |  85%
# pyaudio-0.2.11       | 189 KB    | #########3 |  93%
# pyaudio-0.2.11       | 189 KB    | ########## | 100%
# pyaudio-0.2.11       | 189 KB    | ########## | 100%
#
# conda-4.10.1         | 2.9 MB    |            |   0%
# conda-4.10.1         | 2.9 MB    |            |   1%
# conda-4.10.1         | 2.9 MB    | 1          |   2%
# conda-4.10.1         | 2.9 MB    | 2          |   2%
# conda-4.10.1         | 2.9 MB    | 2          |   3%
# conda-4.10.1         | 2.9 MB    | 3          |   3%
# conda-4.10.1         | 2.9 MB    | 3          |   4%
# conda-4.10.1         | 2.9 MB    | 4          |   4%
# conda-4.10.1         | 2.9 MB    | 4          |   5%
# conda-4.10.1         | 2.9 MB    | 5          |   5%
# conda-4.10.1         | 2.9 MB    | 5          |   6%
# conda-4.10.1         | 2.9 MB    | 6          |   7%
# conda-4.10.1         | 2.9 MB    | 7          |   7%
# conda-4.10.1         | 2.9 MB    | 7          |   8%
# conda-4.10.1         | 2.9 MB    | 8          |   8%
# conda-4.10.1         | 2.9 MB    | 8          |   9%
# conda-4.10.1         | 2.9 MB    | 9          |   9%
# conda-4.10.1         | 2.9 MB    | 9          |  10%
# conda-4.10.1         | 2.9 MB    | #          |  10%
# conda-4.10.1         | 2.9 MB    | #          |  11%
# conda-4.10.1         | 2.9 MB    | #1         |  11%
# conda-4.10.1         | 2.9 MB    | #1         |  12%
# conda-4.10.1         | 2.9 MB    | #2         |  12%
# conda-4.10.1         | 2.9 MB    | #3         |  13%
# conda-4.10.1         | 2.9 MB    | #3         |  14%
# conda-4.10.1         | 2.9 MB    | #4         |  14%
# conda-4.10.1         | 2.9 MB    | #4         |  15%
# conda-4.10.1         | 2.9 MB    | #5         |  15%
# conda-4.10.1         | 2.9 MB    | #5         |  16%
# conda-4.10.1         | 2.9 MB    | #6         |  16%
# conda-4.10.1         | 2.9 MB    | #6         |  17%
# conda-4.10.1         | 2.9 MB    | #7         |  17%
# conda-4.10.1         | 2.9 MB    | #7         |  18%
# conda-4.10.1         | 2.9 MB    | #8         |  18%
# conda-4.10.1         | 2.9 MB    | #9         |  19%
# conda-4.10.1         | 2.9 MB    | #9         |  20%
# conda-4.10.1         | 2.9 MB    | ##3        |  24%
# conda-4.10.1         | 2.9 MB    | ##4        |  25%
# conda-4.10.1         | 2.9 MB    | ##6        |  26%
# conda-4.10.1         | 2.9 MB    | ##7        |  27%
# conda-4.10.1         | 2.9 MB    | ###1       |  32%
# conda-4.10.1         | 2.9 MB    | ###2       |  33%
# conda-4.10.1         | 2.9 MB    | ###3       |  34%
# conda-4.10.1         | 2.9 MB    | ###4       |  35%
# conda-4.10.1         | 2.9 MB    | ###5       |  36%
# conda-4.10.1         | 2.9 MB    | ###6       |  37%
# conda-4.10.1         | 2.9 MB    | ###7       |  37%
# conda-4.10.1         | 2.9 MB    | ###8       |  38%
# conda-4.10.1         | 2.9 MB    | ###8       |  39%
# conda-4.10.1         | 2.9 MB    | ###9       |  39%
# conda-4.10.1         | 2.9 MB    | ###9       |  40%
# conda-4.10.1         | 2.9 MB    | ####       |  40%
# conda-4.10.1         | 2.9 MB    | ####       |  41%
# conda-4.10.1         | 2.9 MB    | ####1      |  41%
# conda-4.10.1         | 2.9 MB    | ####1      |  42%
# conda-4.10.1         | 2.9 MB    | ####2      |  42%
# conda-4.10.1         | 2.9 MB    | ####2      |  43%
# conda-4.10.1         | 2.9 MB    | ####3      |  43%
# conda-4.10.1         | 2.9 MB    | ####4      |  44%
# conda-4.10.1         | 2.9 MB    | ####4      |  45%
# conda-4.10.1         | 2.9 MB    | ####5      |  45%
# conda-4.10.1         | 2.9 MB    | ####5      |  46%
# conda-4.10.1         | 2.9 MB    | ####6      |  46%
# conda-4.10.1         | 2.9 MB    | ####6      |  47%
# conda-4.10.1         | 2.9 MB    | ####7      |  47%
# conda-4.10.1         | 2.9 MB    | ####7      |  48%
# conda-4.10.1         | 2.9 MB    | ####8      |  48%
# conda-4.10.1         | 2.9 MB    | ####8      |  49%
# conda-4.10.1         | 2.9 MB    | ####9      |  49%
# conda-4.10.1         | 2.9 MB    | ####9      |  50%
# conda-4.10.1         | 2.9 MB    | #####      |  51%
# conda-4.10.1         | 2.9 MB    | #####1     |  51%
# conda-4.10.1         | 2.9 MB    | #####1     |  52%
# conda-4.10.1         | 2.9 MB    | #####2     |  52%
# conda-4.10.1         | 2.9 MB    | #####2     |  53%
# conda-4.10.1         | 2.9 MB    | #####3     |  53%
# conda-4.10.1         | 2.9 MB    | #####3     |  54%
# conda-4.10.1         | 2.9 MB    | #####4     |  54%
# conda-4.10.1         | 2.9 MB    | #####4     |  55%
# conda-4.10.1         | 2.9 MB    | #####5     |  55%
# conda-4.10.1         | 2.9 MB    | #####5     |  56%
# conda-4.10.1         | 2.9 MB    | #####6     |  57%
# conda-4.10.1         | 2.9 MB    | #####7     |  57%
# conda-4.10.1         | 2.9 MB    | #####7     |  58%
# conda-4.10.1         | 2.9 MB    | #####8     |  58%
# conda-4.10.1         | 2.9 MB    | #####8     |  59%
# conda-4.10.1         | 2.9 MB    | #####9     |  59%
# conda-4.10.1         | 2.9 MB    | #####9     |  60%
# conda-4.10.1         | 2.9 MB    | ######     |  60%
# conda-4.10.1         | 2.9 MB    | ######     |  61%
# conda-4.10.1         | 2.9 MB    | ######1    |  61%
# conda-4.10.1         | 2.9 MB    | ######1    |  62%
# conda-4.10.1         | 2.9 MB    | ######2    |  62%
# conda-4.10.1         | 2.9 MB    | ######3    |  63%
# conda-4.10.1         | 2.9 MB    | ######4    |  64%
# conda-4.10.1         | 2.9 MB    | #######3   |  73%
# conda-4.10.1         | 2.9 MB    | #######6   |  76%
# conda-4.10.1         | 2.9 MB    | #######8   |  78%
# conda-4.10.1         | 2.9 MB    | #######9   |  80%
# conda-4.10.1         | 2.9 MB    | ########1  |  81%
# conda-4.10.1         | 2.9 MB    | ########2  |  83%
# conda-4.10.1         | 2.9 MB    | ########3  |  84%
# conda-4.10.1         | 2.9 MB    | ########4  |  85%
# conda-4.10.1         | 2.9 MB    | ########6  |  86%
# conda-4.10.1         | 2.9 MB    | ########7  |  87%
# conda-4.10.1         | 2.9 MB    | ########8  |  88%
# conda-4.10.1         | 2.9 MB    | ########8  |  89%
# conda-4.10.1         | 2.9 MB    | ########9  |  89%
# conda-4.10.1         | 2.9 MB    | ########9  |  90%
# conda-4.10.1         | 2.9 MB    | #########  |  90%
# conda-4.10.1         | 2.9 MB    | #########  |  91%
# conda-4.10.1         | 2.9 MB    | #########1 |  91%
# conda-4.10.1         | 2.9 MB    | #########1 |  92%
# conda-4.10.1         | 2.9 MB    | #########2 |  92%
# conda-4.10.1         | 2.9 MB    | #########2 |  93%
# conda-4.10.1         | 2.9 MB    | #########3 |  93%
# conda-4.10.1         | 2.9 MB    | #########3 |  94%
# conda-4.10.1         | 2.9 MB    | #########4 |  95%
# conda-4.10.1         | 2.9 MB    | #########5 |  95%
# conda-4.10.1         | 2.9 MB    | #########5 |  96%
# conda-4.10.1         | 2.9 MB    | #########6 |  96%
# conda-4.10.1         | 2.9 MB    | #########6 |  97%
# conda-4.10.1         | 2.9 MB    | #########9 |  99%
# conda-4.10.1         | 2.9 MB    | ########## | 100%
# conda-4.10.1         | 2.9 MB    | ########## | 100%
#
# portaudio-19.6.0     | 240 KB    |            |   0%
# portaudio-19.6.0     | 240 KB    | 6          |   7%
# portaudio-19.6.0     | 240 KB    | #3         |  13%
# portaudio-19.6.0     | 240 KB    | ##         |  20%
# portaudio-19.6.0     | 240 KB    | ##6        |  27%
# portaudio-19.6.0     | 240 KB    | ###3       |  33%
# portaudio-19.6.0     | 240 KB    | ####       |  40%
# portaudio-19.6.0     | 240 KB    | ####6      |  47%
# portaudio-19.6.0     | 240 KB    | #####3     |  53%
# portaudio-19.6.0     | 240 KB    | ######     |  60%

# %%
pip install pywhatkit
# Out:
# portaudio-19.6.0     | 240 KB    | ######6    |  67%
# portaudio-19.6.0     | 240 KB    | #######3   |  73%
# portaudio-19.6.0     | 240 KB    | ########## | 100%
# portaudio-19.6.0     | 240 KB    | ########## | 100%
#
# openssl-1.1.1h       | 5.8 MB    |            |   0%
# openssl-1.1.1h       | 5.8 MB    |            |   0%
# openssl-1.1.1h       | 5.8 MB    |            |   1%
# openssl-1.1.1h       | 5.8 MB    |            |   1%
# openssl-1.1.1h       | 5.8 MB    | 1          |   1%
# openssl-1.1.1h       | 5.8 MB    | 1          |   1%
# openssl-1.1.1h       | 5.8 MB    | 1          |   2%
# openssl-1.1.1h       | 5.8 MB    | 1          |   2%
# openssl-1.1.1h       | 5.8 MB    | 2          |   2%
# openssl-1.1.1h       | 5.8 MB    | 2          |   2%
# openssl-1.1.1h       | 5.8 MB    | 2          |   3%
# openssl-1.1.1h       | 5.8 MB    | 4          |   5%
# openssl-1.1.1h       | 5.8 MB    | 5          |   5%
# openssl-1.1.1h       | 5.8 MB    | 5          |   6%
# openssl-1.1.1h       | 5.8 MB    | 6          |   7%
# openssl-1.1.1h       | 5.8 MB    | 6          |   7%
# openssl-1.1.1h       | 5.8 MB    | 7          |   7%
# openssl-1.1.1h       | 5.8 MB    | 7          |   7%
# openssl-1.1.1h       | 5.8 MB    | 7          |   8%
# openssl-1.1.1h       | 5.8 MB    | 7          |   8%
# openssl-1.1.1h       | 5.8 MB    | 8          |   8%
# openssl-1.1.1h       | 5.8 MB    | 8          |   8%
# openssl-1.1.1h       | 5.8 MB    | 8          |   9%
# openssl-1.1.1h       | 5.8 MB    | 9          |  10%
# openssl-1.1.1h       | 5.8 MB    | #          |  10%
# openssl-1.1.1h       | 5.8 MB    | #          |  11%
# openssl-1.1.1h       | 5.8 MB    | #          |  11%
# openssl-1.1.1h       | 5.8 MB    | #1         |  11%
# openssl-1.1.1h       | 5.8 MB    | #1         |  11%
# openssl-1.1.1h       | 5.8 MB    | #1         |  12%
# openssl-1.1.1h       | 5.8 MB    | #2         |  12%
# openssl-1.1.1h       | 5.8 MB    | #2         |  13%
# openssl-1.1.1h       | 5.8 MB    | #3         |  13%
# openssl-1.1.1h       | 5.8 MB    | #3         |  13%
# openssl-1.1.1h       | 5.8 MB    | #3         |  14%
# openssl-1.1.1h       | 5.8 MB    | #4         |  14%
# openssl-1.1.1h       | 5.8 MB    | #4         |  14%
# openssl-1.1.1h       | 5.8 MB    | #4         |  15%
# openssl-1.1.1h       | 5.8 MB    | #4         |  15%
# openssl-1.1.1h       | 5.8 MB    | #5         |  15%
# openssl-1.1.1h       | 5.8 MB    | #5         |  15%
# openssl-1.1.1h       | 5.8 MB    | #6         |  16%
# openssl-1.1.1h       | 5.8 MB    | #6         |  16%
# openssl-1.1.1h       | 5.8 MB    | #6         |  17%
# openssl-1.1.1h       | 5.8 MB    | #6         |  17%
# openssl-1.1.1h       | 5.8 MB    | #7         |  17%
# openssl-1.1.1h       | 5.8 MB    | #7         |  17%
# openssl-1.1.1h       | 5.8 MB    | #7         |  18%
# openssl-1.1.1h       | 5.8 MB    | #7         |  18%
# openssl-1.1.1h       | 5.8 MB    | #8         |  18%
# openssl-1.1.1h       | 5.8 MB    | #8         |  18%
# openssl-1.1.1h       | 5.8 MB    | #8         |  19%
# openssl-1.1.1h       | 5.8 MB    | #9         |  19%
# openssl-1.1.1h       | 5.8 MB    | #9         |  20%
# openssl-1.1.1h       | 5.8 MB    | ##         |  20%
# openssl-1.1.1h       | 5.8 MB    | ##         |  21%
# openssl-1.1.1h       | 5.8 MB    | ##         |  21%
# openssl-1.1.1h       | 5.8 MB    | ##1        |  21%
# openssl-1.1.1h       | 5.8 MB    | ##1        |  21%
# openssl-1.1.1h       | 5.8 MB    | ##2        |  22%
# openssl-1.1.1h       | 5.8 MB    | ##2        |  23%
# openssl-1.1.1h       | 5.8 MB    | ##2        |  23%
# openssl-1.1.1h       | 5.8 MB    | ##3        |  23%
# openssl-1.1.1h       | 5.8 MB    | ##3        |  23%
# openssl-1.1.1h       | 5.8 MB    | ##3        |  24%
# openssl-1.1.1h       | 5.8 MB    | ##3        |  24%
# openssl-1.1.1h       | 5.8 MB    | ##4        |  24%
# openssl-1.1.1h       | 5.8 MB    | ##4        |  24%
# openssl-1.1.1h       | 5.8 MB    | ##4        |  25%
# openssl-1.1.1h       | 5.8 MB    | ##4        |  25%
# openssl-1.1.1h       | 5.8 MB    | ##5        |  25%
# openssl-1.1.1h       | 5.8 MB    | ##5        |  26%
# openssl-1.1.1h       | 5.8 MB    | ##5        |  26%
# openssl-1.1.1h       | 5.8 MB    | ##7        |  27%
# openssl-1.1.1h       | 5.8 MB    | ##7        |  28%
# openssl-1.1.1h       | 5.8 MB    | ##7        |  28%
# openssl-1.1.1h       | 5.8 MB    | ##8        |  28%
# openssl-1.1.1h       | 5.8 MB    | ##8        |  29%
# openssl-1.1.1h       | 5.8 MB    | ##8        |  29%
# openssl-1.1.1h       | 5.8 MB    | ##9        |  29%
# openssl-1.1.1h       | 5.8 MB    | ##9        |  29%
# openssl-1.1.1h       | 5.8 MB    | ##9        |  30%
# openssl-1.1.1h       | 5.8 MB    | ##9        |  30%
# openssl-1.1.1h       | 5.8 MB    | ###        |  30%
# openssl-1.1.1h       | 5.8 MB    | ###        |  30%
# openssl-1.1.1h       | 5.8 MB    | ###        |  31%
# openssl-1.1.1h       | 5.8 MB    | ###        |  31%
# openssl-1.1.1h       | 5.8 MB    | ###1       |  31%
# openssl-1.1.1h       | 5.8 MB    | ###1       |  32%
# openssl-1.1.1h       | 5.8 MB    | ###1       |  32%
# openssl-1.1.1h       | 5.8 MB    | ###2       |  32%
# openssl-1.1.1h       | 5.8 MB    | ###2       |  32%
# openssl-1.1.1h       | 5.8 MB    | ###4       |  34%
# openssl-1.1.1h       | 5.8 MB    | ###5       |  35%
# openssl-1.1.1h       | 5.8 MB    | ###5       |  36%
# openssl-1.1.1h       | 5.8 MB    | ###6       |  36%
# openssl-1.1.1h       | 5.8 MB    | ###6       |  36%
# openssl-1.1.1h       | 5.8 MB    | ###6       |  37%
# openssl-1.1.1h       | 5.8 MB    | ###7       |  37%
# openssl-1.1.1h       | 5.8 MB    | ###7       |  38%
# openssl-1.1.1h       | 5.8 MB    | ###8       |  38%
# openssl-1.1.1h       | 5.8 MB    | ###8       |  39%
# openssl-1.1.1h       | 5.8 MB    | ###9       |  39%
# openssl-1.1.1h       | 5.8 MB    | ###9       |  40%
# openssl-1.1.1h       | 5.8 MB    | ####       |  40%
# openssl-1.1.1h       | 5.8 MB    | ####       |  40%
# openssl-1.1.1h       | 5.8 MB    | ####       |  41%
# openssl-1.1.1h       | 5.8 MB    | ####1      |  41%
# openssl-1.1.1h       | 5.8 MB    | ####1      |  41%
# openssl-1.1.1h       | 5.8 MB    | ####1      |  42%
# openssl-1.1.1h       | 5.8 MB    | ####1      |  42%
# openssl-1.1.1h       | 5.8 MB    | ####2      |  42%
# openssl-1.1.1h       | 5.8 MB    | ####2      |  42%
# openssl-1.1.1h       | 5.8 MB    | ####2      |  43%
# openssl-1.1.1h       | 5.8 MB    | ####3      |  43%
# openssl-1.1.1h       | 5.8 MB    | ####3      |  43%
# openssl-1.1.1h       | 5.8 MB    | ####3      |  44%
# openssl-1.1.1h       | 5.8 MB    | ####4      |  44%
# openssl-1.1.1h       | 5.8 MB    | ####4      |  44%
# openssl-1.1.1h       | 5.8 MB    | ####5      |  45%
# openssl-1.1.1h       | 5.8 MB    | ####5      |  45%
# openssl-1.1.1h       | 5.8 MB    | ####5      |  46%
# openssl-1.1.1h       | 5.8 MB    | ####5      |  46%
# openssl-1.1.1h       | 5.8 MB    | ####6      |  46%
# openssl-1.1.1h       | 5.8 MB    | ####6      |  46%
# openssl-1.1.1h       | 5.8 MB    | ####6      |  47%
# openssl-1.1.1h       | 5.8 MB    | ####7      |  47%
# openssl-1.1.1h       | 5.8 MB    | ####7      |  48%
# openssl-1.1.1h       | 5.8 MB    | ####8      |  48%
# openssl-1.1.1h       | 5.8 MB    | ####8      |  48%
# openssl-1.1.1h       | 5.8 MB    | ####8      |  49%
# openssl-1.1.1h       | 5.8 MB    | ####9      |  49%
# openssl-1.1.1h       | 5.8 MB    | ####9      |  49%
# openssl-1.1.1h       | 5.8 MB    | ####9      |  50%
# openssl-1.1.1h       | 5.8 MB    | ####9      |  50%
# openssl-1.1.1h       | 5.8 MB    | #####      |  50%
# openssl-1.1.1h       | 5.8 MB    | #####      |  51%
# openssl-1.1.1h       | 5.8 MB    | #####      |  51%
# openssl-1.1.1h       | 5.8 MB    | #####1     |  51%
# openssl-1.1.1h       | 5.8 MB    | #####1     |  51%
# openssl-1.1.1h       | 5.8 MB    | #####1     |  52%
# openssl-1.1.1h       | 5.8 MB    | #####1     |  52%
# openssl-1.1.1h       | 5.8 MB    | #####2     |  52%
# openssl-1.1.1h       | 5.8 MB    | #####2     |  52%
# openssl-1.1.1h       | 5.8 MB    | #####2     |  53%
# openssl-1.1.1h       | 5.8 MB    | #####2     |  53%
# openssl-1.1.1h       | 5.8 MB    | #####3     |  54%
# openssl-1.1.1h       | 5.8 MB    | #####4     |  54%
# openssl-1.1.1h       | 5.8 MB    | #####4     |  55%
# openssl-1.1.1h       | 5.8 MB    | #####5     |  55%
# openssl-1.1.1h       | 5.8 MB    | #####5     |  56%
# openssl-1.1.1h       | 5.8 MB    | #####5     |  56%
# openssl-1.1.1h       | 5.8 MB    | #####6     |  57%
# openssl-1.1.1h       | 5.8 MB    | #####6     |  57%
# openssl-1.1.1h       | 5.8 MB    | #####7     |  57%
# openssl-1.1.1h       | 5.8 MB    | #####7     |  57%
# openssl-1.1.1h       | 5.8 MB    | #####7     |  58%
# openssl-1.1.1h       | 5.8 MB    | #####7     |  58%
# openssl-1.1.1h       | 5.8 MB    | #####8     |  58%
# openssl-1.1.1h       | 5.8 MB    | #####8     |  58%
# openssl-1.1.1h       | 5.8 MB    | #####8     |  59%
# openssl-1.1.1h       | 5.8 MB    | #####9     |  59%
# openssl-1.1.1h       | 5.8 MB    | #####9     |  60%
# openssl-1.1.1h       | 5.8 MB    | #####9     |  60%
# openssl-1.1.1h       | 5.8 MB    | ######     |  60%
# openssl-1.1.1h       | 5.8 MB    | ######     |  60%
# openssl-1.1.1h       | 5.8 MB    | ######     |  61%
# openssl-1.1.1h       | 5.8 MB    | ######     |  61%
# openssl-1.1.1h       | 5.8 MB    | ######1    |  61%
# openssl-1.1.1h       | 5.8 MB    | ######1    |  61%
# openssl-1.1.1h       | 5.8 MB    | ######1    |  62%
# openssl-1.1.1h       | 5.8 MB    | ######1    |  62%
# openssl-1.1.1h       | 5.8 MB    | ######2    |  62%
# openssl-1.1.1h       | 5.8 MB    | ######2    |  62%
# openssl-1.1.1h       | 5.8 MB    | ######3    |  63%
# openssl-1.1.1h       | 5.8 MB    | ######3    |  64%
# openssl-1.1.1h       | 5.8 MB    | ######3    |  64%
# openssl-1.1.1h       | 5.8 MB    | ######4    |  64%
# openssl-1.1.1h       | 5.8 MB    | ######4    |  64%
# openssl-1.1.1h       | 5.8 MB    | ######4    |  65%
# openssl-1.1.1h       | 5.8 MB    | ######5    |  65%
# openssl-1.1.1h       | 5.8 MB    | ######5    |  66%
# openssl-1.1.1h       | 5.8 MB    | ######6    |  66%
# openssl-1.1.1h       | 5.8 MB    | ######6    |  66%
# openssl-1.1.1h       | 5.8 MB    | ######6    |  67%
# openssl-1.1.1h       | 5.8 MB    | ######6    |  67%
# openssl-1.1.1h       | 5.8 MB    | ######7    |  67%
# openssl-1.1.1h       | 5.8 MB    | ######7    |  68%
# openssl-1.1.1h       | 5.8 MB    | ######7    |  68%
# openssl-1.1.1h       | 5.8 MB    | ######8    |  68%
# openssl-1.1.1h       | 5.8 MB    | ######8    |  68%
# openssl-1.1.1h       | 5.8 MB    | ######8    |  69%
# openssl-1.1.1h       | 5.8 MB    | ######9    |  69%
# openssl-1.1.1h       | 5.8 MB    | ######9    |  69%
# openssl-1.1.1h       | 5.8 MB    | ######9    |  70%
# openssl-1.1.1h       | 5.8 MB    | ######9    |  70%
# openssl-1.1.1h       | 5.8 MB    | #######    |  70%
# openssl-1.1.1h       | 5.8 MB    | #######    |  70%
# openssl-1.1.1h       | 5.8 MB    | #######    |  71%
# openssl-1.1.1h       | 5.8 MB    | #######    |  71%
# openssl-1.1.1h       | 5.8 MB    | #######1   |  71%
# openssl-1.1.1h       | 5.8 MB    | #######1   |  71%
# openssl-1.1.1h       | 5.8 MB    | #######1   |  72%
# openssl-1.1.1h       | 5.8 MB    | #######2   |  72%
# openssl-1.1.1h       | 5.8 MB    | #######2   |  72%
# openssl-1.1.1h       | 5.8 MB    | #######2   |  73%
# openssl-1.1.1h       | 5.8 MB    | #######2   |  73%
# openssl-1.1.1h       | 5.8 MB    | #######3   |  73%
# openssl-1.1.1h       | 5.8 MB    | #######3   |  74%
# openssl-1.1.1h       | 5.8 MB    | #######3   |  74%
# openssl-1.1.1h       | 5.8 MB    | #######5   |  75%
# openssl-1.1.1h       | 5.8 MB    | #######5   |  76%
# openssl-1.1.1h       | 5.8 MB    | #######6   |  77%
# openssl-1.1.1h       | 5.8 MB    | #######7   |  77%
# openssl-1.1.1h       | 5.8 MB    | #######7   |  78%
# openssl-1.1.1h       | 5.8 MB    | #######8   |  78%
# openssl-1.1.1h       | 5.8 MB    | #######8   |  79%
# openssl-1.1.1h       | 5.8 MB    | #######9   |  79%
# openssl-1.1.1h       | 5.8 MB    | #######9   |  80%
# openssl-1.1.1h       | 5.8 MB    | #######9   |  80%
# openssl-1.1.1h       | 5.8 MB    | ########   |  80%
# openssl-1.1.1h       | 5.8 MB    | ########   |  80%
# openssl-1.1.1h       | 5.8 MB    | ########   |  81%
# openssl-1.1.1h       | 5.8 MB    | ########   |  81%
# openssl-1.1.1h       | 5.8 MB    | ########1  |  81%
# openssl-1.1.1h       | 5.8 MB    | ########1  |  82%
# openssl-1.1.1h       | 5.8 MB    | ########1  |  82%
# openssl-1.1.1h       | 5.8 MB    | ########2  |  82%
# openssl-1.1.1h       | 5.8 MB    | ########2  |  83%
# openssl-1.1.1h       | 5.8 MB    | ########3  |  83%
# openssl-1.1.1h       | 5.8 MB    | ########3  |  83%
# openssl-1.1.1h       | 5.8 MB    | ########4  |  84%
# openssl-1.1.1h       | 5.8 MB    | ########4  |  85%
# openssl-1.1.1h       | 5.8 MB    | ########4  |  85%
# openssl-1.1.1h       | 5.8 MB    | ########5  |  85%
# openssl-1.1.1h       | 5.8 MB    | ########5  |  86%
# openssl-1.1.1h       | 5.8 MB    | ########5  |  86%
# openssl-1.1.1h       | 5.8 MB    | ########6  |  86%
# openssl-1.1.1h       | 5.8 MB    | ########6  |  87%
# openssl-1.1.1h       | 5.8 MB    | ########7  |  87%
# openssl-1.1.1h       | 5.8 MB    | ########7  |  88%
# openssl-1.1.1h       | 5.8 MB    | ########8  |  88%
# openssl-1.1.1h       | 5.8 MB    | ########8  |  88%
# openssl-1.1.1h       | 5.8 MB    | ########8  |  89%
# openssl-1.1.1h       | 5.8 MB    | ########8  |  89%
# openssl-1.1.1h       | 5.8 MB    | ########9  |  89%
# openssl-1.1.1h       | 5.8 MB    | ########9  |  89%
# openssl-1.1.1h       | 5.8 MB    | ########9  |  90%
# openssl-1.1.1h       | 5.8 MB    | #########  |  90%
# openssl-1.1.1h       | 5.8 MB    | #########  |  90%
# openssl-1.1.1h       | 5.8 MB    | #########  |  91%
# openssl-1.1.1h       | 5.8 MB    | #########1 |  91%
# openssl-1.1.1h       | 5.8 MB    | #########1 |  91%
# openssl-1.1.1h       | 5.8 MB    | #########1 |  92%
# openssl-1.1.1h       | 5.8 MB    | #########1 |  92%
# openssl-1.1.1h       | 5.8 MB    | #########2 |  92%
# openssl-1.1.1h       | 5.8 MB    | #########2 |  92%
# openssl-1.1.1h       | 5.8 MB    | #########2 |  93%
# openssl-1.1.1h       | 5.8 MB    | #########2 |  93%
# openssl-1.1.1h       | 5.8 MB    | #########3 |  93%
# openssl-1.1.1h       | 5.8 MB    | #########3 |  93%
# openssl-1.1.1h       | 5.8 MB    | #########4 |  94%
# openssl-1.1.1h       | 5.8 MB    | #########4 |  94%
# openssl-1.1.1h       | 5.8 MB    | #########4 |  95%
# openssl-1.1.1h       | 5.8 MB    | #########5 |  95%
# openssl-1.1.1h       | 5.8 MB    | #########5 |  96%
# openssl-1.1.1h       | 5.8 MB    | #########6 |  96%
# openssl-1.1.1h       | 5.8 MB    | #########6 |  96%
# openssl-1.1.1h       | 5.8 MB    | #########6 |  97%
# openssl-1.1.1h       | 5.8 MB    | #########6 |  97%
# openssl-1.1.1h       | 5.8 MB    | #########7 |  97%
# openssl-1.1.1h       | 5.8 MB    | #########7 |  98%
# openssl-1.1.1h       | 5.8 MB    | #########7 |  98%
# openssl-1.1.1h       | 5.8 MB    | #########8 |  98%
# openssl-1.1.1h       | 5.8 MB    | #########8 |  99%
# openssl-1.1.1h       | 5.8 MB    | #########9 |  99%
# openssl-1.1.1h       | 5.8 MB    | #########9 | 100%
# openssl-1.1.1h       | 5.8 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting pywhatkit
#   Using cached pywhatkit-4.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from pywhatkit) (2.24.0)
# Requirement already satisfied: Pillow in c:\anaconda\lib\site-packages (from pywhatkit) (8.0.1)
# Collecting pyautogui
#   Using cached PyAutoGUI-0.9.52.tar.gz (55 kB)
# Collecting wikipedia
#   Using cached wikipedia-1.4.0.tar.gz (27 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->pywhatkit) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->pywhatkit) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\anaconda\lib\site-packages (from requests->pywhatkit) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\anaconda\lib\site-packages (from requests->pywhatkit) (2.10)
# Collecting pymsgbox
#   Using cached PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting PyTweening>=1.0.1
#   Using cached PyTweening-1.0.3.zip (15 kB)
# Collecting pyscreeze>=0.1.21
#   Using cached PyScreeze-0.1.27.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting pygetwindow>=0.0.5
#   Using cached PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Using cached MouseInfo-0.1.3.tar.gz (10 kB)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\lib\site-packages (from wikipedia->pywhatkit) (4.9.3)
# Note: you may need to restart the kernel to use updated packages.Collecting pyrect
#
#   Using cached PyRect-0.1.4.tar.gz (15 kB)
# Collecting pyperclip
#   Using cached pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\anaconda\lib\site-packages (from beautifulsoup4->wikipedia->pywhatkit) (2.0.1)
# Building wheels for collected packages: pyautogui, wikipedia, pymsgbox, PyTweening, pyscreeze, pygetwindow, mouseinfo, pyrect, pyperclip
#   Building wheel for pyautogui (setup.py): started
#   Building wheel for pyautogui (setup.py): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.52-py3-none-any.whl size=35198 sha256=37fc50c9215f651fa1b909d22c219af4dedfe8f4c551ca7f75745fa86b94b7c2
#   Stored in directory: c:\users\this pc\appdata\local\pip\cache\wheels\4d\0d\6a\4258cb741835ea9ce7897652ae88272d3baf5cb1944c1984aa
#   Building wheel for wikipedia (setup.py): started
#   Building wheel for wikipedia (setup.py): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11689 sha256=de1eb87874e7fef6a4d54289459bf1295778995117a1718fe3759d981ba8e8ac
#   Stored in directory: c:\users\this pc\appdata\local\pip\cache\wheels\07\93\05\72c05349177dca2e0ba31a33ba4f7907606f7ddef303517c6a
#   Building wheel for pymsgbox (PEP 517): started
#   Building wheel for pymsgbox (PEP 517): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7420 sha256=6275a78d9f007c300d8613ae02f2d2b445274b3774696df59553761e9b8fa8f4
#   Stored in directory: c:\users\this pc\appdata\local\pip\cache\wheels\91\28\0d\f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for PyTweening (setup.py): started
#   Building wheel for PyTweening (setup.py): finished with status 'done'
#   Created wheel for PyTweening: filename=PyTweening-1.0.3-py3-none-any.whl size=3820 sha256=a8494cb331fb8f4b26cfa388ee06545ba27e060c233cc6b1de31cf69b24cfb3f
#   Stored in directory: c:\users\this pc\appdata\local\pip\cache\wheels\e7\50\20\790fbd95739abfdf0348bef99d5cc0c7c2930a19a91f602ddc
#   Building wheel for pyscreeze (PEP 517): started
#   Building wheel for pyscreeze (PEP 517): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.27-py3-none-any.whl size=12864 sha256=659cc2c901dae53d5430f0ae357ec61d152b37d3b770df63ddb2117d5fcb952c
#   Stored in directory: c:\users\this pc\appdata\local\pip\cache\wheels\f7\91\eb\c0fa176c095c77460a579ef339f24a377474b041e5543d1a00
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11084 sha256=4c99ab6bc828b6a21d4e5f46417292b6708d34f1305959088a0624dcacbd0795
#   Stored in directory: c:\users\this pc\appdata\local\pip\cache\wheels\91\e3\04\184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10910 sha256=b59631051f5a98d6f9bce4a0d9815de56c70b8fdb87fc52467b987553a770789
#   Stored in directory: c:\users\this pc\appdata\local\pip\cache\wheels\d1\72\fb\35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.1.4-py2.py3-none-any.whl size=9552 sha256=e9e8f837ef26fa4d58c18b97c6f7ac320ebc8c7fde5bedfa3703458078559067
#   Stored in directory: c:\users\this pc\appdata\local\pip\cache\wheels\d1\e4\47\c62f8291b16b6df7e89ac885881ff71f35ca04c6e384251de9
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11112 sha256=6413a4b763687a82faf85e7956c3214a6003fa72292c24c9f27f8f785511f0c6
#   Stored in directory: c:\users\this pc\appdata\local\pip\cache\wheels\7f\1a\65\84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
# Successfully built pyautogui wikipedia pymsgbox PyTweening pyscreeze pygetwindow mouseinfo pyrect pyperclip
# Installing collected packages: pymsgbox, PyTweening, pyscreeze, pyrect, pygetwindow, pyperclip, mouseinfo, pyautogui, wikipedia, pywhatkit
# Successfully installed PyTweening-1.0.3 mouseinfo-0.1.3 pyautogui-0.9.52 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.1.4 pyscreeze-0.1.27 pywhatkit-4.1 wikipedia-1.4.0

# %%
pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in c:\anaconda\lib\site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\lib\site-packages (from wikipedia) (4.9.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\anaconda\lib\site-packages (from wikipedia) (2.24.0)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\anaconda\lib\site-packages (from beautifulsoup4->wikipedia) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import pywhatkit
import wikipedia
listener = sr.Recognizer()
alexa = pyttsx3.init()

voices = alexa.getProperty('voices')
alexa.setProperty('voice', voices[1].id)

def talk(text):
    alexa.say(text)
    alexa.runAndWait()

def take_command():
    
    try:
        with sr.Microphone() as source:
            print('Device is listening, please speak...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice)
            command = command.lower()
            if 'alexa' in command:
                command = command.replace('alexa', '')
    except:   
        pass
    return command

def run_alexa():
    command = take_command()
    
    if 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')
        print('Current time is ' + time)
        talk('Current time is ' + time) 
    elif 'play' in command:
        song = command.replace('play', '')
        talk('playing ' + song)
        pywhatkit.playonyt(song)
    elif 'tell me about' in command:
        wiki = command.replace('tell me about', '')
        info = wikipedia.summary(wiki, 2)
        print(info)
        talk(info)
    else:
        talk('Sorry I didnot get your question, I can search it from google')
        pywhatkit.search(command)
             
        
run_alexa()
# Out:
# Device is listening, please speak...
